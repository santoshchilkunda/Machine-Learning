# %% [markdown]
# https://github.com/tensorflow/tensorflow/blob/master/tensorflow/examples/udacity/4_convolutions.ipynb

# %% [markdown]
# # Deep Learning
#
# # Assignment 4
#
# Previously in 2_fullyconnected.ipynb and 3_regularization.ipynb, we trained fully connected networks to classify notMNIST characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %% [markdown]
# First reload the data we generated in 1_notmnist.ipynb.

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.329807
# Minibatch accuracy: 6.2%
# Validation accuracy: 14.3%
# Minibatch loss at step 50: 2.036012
# Minibatch accuracy: 12.5%
# Validation accuracy: 46.4%
# Minibatch loss at step 100: 1.143393
# Minibatch accuracy: 50.0%
# Validation accuracy: 63.7%
# Minibatch loss at step 150: 0.599536
# Minibatch accuracy: 75.0%
# Validation accuracy: 74.9%
# Minibatch loss at step 200: 1.149982
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 250: 1.328308
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.7%
# Minibatch loss at step 300: 0.491255
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.4%
# Minibatch loss at step 350: 0.534223
# Minibatch accuracy: 87.5%
# Validation accuracy: 75.9%
# Minibatch loss at step 400: 0.207223
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.1%
# Minibatch loss at step 450: 0.857128
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.2%
# Minibatch loss at step 500: 0.794583
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.6%
# Minibatch loss at step 550: 0.889458
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.4%
# Minibatch loss at step 600: 0.268568
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.8%
# Minibatch loss at step 650: 1.025098
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 700: 0.815279
# Minibatch accuracy: 62.5%
# Validation accuracy: 81.7%
# Minibatch loss at step 750: 0.085539
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 800: 0.734003
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.3%
# Minibatch loss at step 850: 0.854458
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.7%
# Minibatch loss at step 900: 0.658146
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.2%
# Minibatch loss at step 950: 0.699581
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.5%
# Minibatch loss at step 1000: 0.448296
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.8%
# Test accuracy: 89.9%

# %% [markdown]
# # Problem 1
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (nn.max_pool()) of stride 2 and kernel size 2.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pooling = tf.nn.max_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
    conv = tf.nn.conv2d(pooling, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pooling = tf.nn.max_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
    shape = pooling.get_shape().as_list()
    reshape = tf.reshape(pooling, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 4.110712
# Minibatch accuracy: 12.5%
# Validation accuracy: 9.9%
# Minibatch loss at step 50: 1.659910
# Minibatch accuracy: 31.2%
# Validation accuracy: 42.1%
# Minibatch loss at step 100: 1.054601
# Minibatch accuracy: 68.8%
# Validation accuracy: 60.8%
# Minibatch loss at step 150: 0.406545
# Minibatch accuracy: 93.8%
# Validation accuracy: 72.4%
# Minibatch loss at step 200: 0.828088
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.3%
# Minibatch loss at step 250: 1.146773
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.9%
# Minibatch loss at step 300: 0.350425
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.5%
# Minibatch loss at step 350: 0.493469
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.0%
# Minibatch loss at step 400: 0.300577
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.0%
# Minibatch loss at step 450: 0.777384
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.4%
# Minibatch loss at step 500: 0.736927
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.1%
# Minibatch loss at step 550: 0.530529
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.0%
# Minibatch loss at step 600: 0.412505
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.6%
# Minibatch loss at step 650: 0.773090
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 700: 0.900745
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.4%
# Minibatch loss at step 750: 0.032217
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.8%
# Minibatch loss at step 800: 0.598292
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.5%
# Minibatch loss at step 850: 0.600344
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss at step 900: 0.600657
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.0%
# Minibatch loss at step 950: 0.544946
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.1%
# Minibatch loss at step 1000: 0.444482
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.8%
# Test accuracy: 90.1%

# %% [markdown]
# # Problem 2
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic LeNet5 architecture, adding Dropout, and/or adding learning rate decay.

# %%
# with dropout 
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 512

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer5_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer5_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  global_step = tf.Variable(0) # count the number of steps taken
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pooling = tf.nn.max_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
    conv = tf.nn.conv2d(pooling, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    conv = tf.nn.conv2d(pooling, layer5_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer5_biases)
    pooling = tf.nn.max_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
    shape = pooling.get_shape().as_list()
    reshape = tf.reshape(pooling, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.dropout(tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases), keep_prob=0.5)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  learning_rate = tf.train.exponential_decay(0.05, global_step, 1000, 0.85, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 5001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 100 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 13.125305
# Minibatch accuracy: 18.8%
# Validation accuracy: 9.9%
# Minibatch loss at step 100: 1.335151
# Minibatch accuracy: 62.5%
# Validation accuracy: 67.1%
# Minibatch loss at step 200: 1.092326
# Minibatch accuracy: 68.8%
# Validation accuracy: 75.2%
# Minibatch loss at step 300: 0.390572
# Minibatch accuracy: 93.8%
# Validation accuracy: 76.5%
# Minibatch loss at step 400: 0.257239
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.0%
# Minibatch loss at step 500: 0.537865
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.1%
# Minibatch loss at step 600: 0.472770
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.7%
# Minibatch loss at step 700: 0.959798
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.5%
# Minibatch loss at step 800: 0.625112
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.5%
# Minibatch loss at step 900: 0.870629
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 1000: 0.508688
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.8%
# Minibatch loss at step 1100: 0.656501
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 1200: 0.865831
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.7%
# Minibatch loss at step 1300: 0.320954
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.7%
# Minibatch loss at step 1400: 0.508424
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.5%
# Minibatch loss at step 1500: 1.016094
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.5%
# Minibatch loss at step 1600: 1.245885
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.5%
# Minibatch loss at step 1700: 0.658662
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.1%
# Minibatch loss at step 1800: 0.420611
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.8%
# Minibatch loss at step 1900: 0.521665
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.3%
# Minibatch loss at step 2000: 0.160350
# Minibatch accuracy: 100.0%
# Validation accuracy: 84.5%
# Minibatch loss at step 2100: 0.222232
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.6%
# Minibatch loss at step 2200: 0.355927
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.7%
# Minibatch loss at step 2300: 0.715015
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.7%
# Minibatch loss at step 2400: 0.474855
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.8%
# Minibatch loss at step 2500: 1.050645
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.8%
# Minibatch loss at step 2600: 0.366921
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.0%
# Minibatch loss at step 2700: 0.690417
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.0%
# Minibatch loss at step 2800: 0.339863
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.9%
# Minibatch loss at step 2900: 0.339744
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.9%
# Minibatch loss at step 3000: 0.649857
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.5%
# Minibatch loss at step 3100: 0.398147
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.2%
# Minibatch loss at step 3200: 0.271057
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.6%
# Minibatch loss at step 3300: 0.168612
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.4%
# Minibatch loss at step 3400: 0.530652
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.6%
# Minibatch loss at step 3500: 0.327603
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.4%
# Minibatch loss at step 3600: 0.132577
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.4%
# Minibatch loss at step 3700: 1.062257
# Minibatch accuracy: 56.2%
# Validation accuracy: 85.6%
# Minibatch loss at step 3800: 0.040154
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.8%
# Minibatch loss at step 3900: 0.467826
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.2%
# Minibatch loss at step 4000: 0.356293
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 4100: 0.486509
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.3%
# Minibatch loss at step 4200: 0.294090
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.0%
# Minibatch loss at step 4300: 0.777312
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.2%
# Minibatch loss at step 4400: 1.628049
# Minibatch accuracy: 62.5%
# Validation accuracy: 86.1%
# Minibatch loss at step 4500: 0.680945
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.0%
# Minibatch loss at step 4600: 0.595471
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.6%
# Minibatch loss at step 4700: 0.467682
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 4800: 0.339307
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.6%
# Minibatch loss at step 4900: 0.089453
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.2%
# Minibatch loss at step 5000: 0.986469
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.6%
# Test accuracy: 92.7%

# %%
# no drop out
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 512

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer5_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer5_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  global_step = tf.Variable(0) # count the number of steps taken
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pooling = tf.nn.max_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
    conv = tf.nn.conv2d(pooling, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    conv = tf.nn.conv2d(pooling, layer5_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer5_biases)
    pooling = tf.nn.max_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
    shape = pooling.get_shape().as_list()
    reshape = tf.reshape(pooling, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  learning_rate = tf.train.exponential_decay(0.05, global_step, 1000, 0.85, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 5001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 100 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 6.203568
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 100: 0.884589
# Minibatch accuracy: 62.5%
# Validation accuracy: 70.0%
# Minibatch loss at step 200: 1.002205
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.2%
# Minibatch loss at step 300: 0.333772
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.4%
# Minibatch loss at step 400: 0.122770
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.1%
# Minibatch loss at step 500: 0.872361
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.7%
# Minibatch loss at step 600: 0.297113
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.0%
# Minibatch loss at step 700: 1.035210
# Minibatch accuracy: 62.5%
# Validation accuracy: 83.2%
# Minibatch loss at step 800: 0.444448
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.0%
# Minibatch loss at step 900: 0.586675
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.8%
# Minibatch loss at step 1000: 0.459298
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.3%
# Minibatch loss at step 1100: 0.574296
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.9%
# Minibatch loss at step 1200: 0.874495
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.7%
# Minibatch loss at step 1300: 0.432925
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.7%
# Minibatch loss at step 1400: 0.449973
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 1500: 0.675865
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.2%
# Minibatch loss at step 1600: 1.115215
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.4%
# Minibatch loss at step 1700: 0.644165
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.1%
# Minibatch loss at step 1800: 0.193661
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.7%
# Minibatch loss at step 1900: 0.307629
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.1%
# Minibatch loss at step 2000: 0.097769
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.7%
# Minibatch loss at step 2100: 0.148169
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.6%
# Minibatch loss at step 2200: 0.364357
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.9%
# Minibatch loss at step 2300: 0.372373
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.9%
# Minibatch loss at step 2400: 0.535070
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.0%
# Minibatch loss at step 2500: 0.881996
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.0%
# Minibatch loss at step 2600: 0.145619
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.2%
# Minibatch loss at step 2700: 0.314754
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# Minibatch loss at step 2800: 0.387934
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 2900: 0.319624
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 3000: 0.769938
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.5%
# Minibatch loss at step 3100: 0.277370
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 3200: 0.281667
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.5%
# Minibatch loss at step 3300: 0.072322
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.8%
# Minibatch loss at step 3400: 0.430770
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.1%
# Minibatch loss at step 3500: 0.269971
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 3600: 0.063070
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.6%
# Minibatch loss at step 3700: 1.070203
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 3800: 0.005157
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.1%
# Minibatch loss at step 3900: 0.476397
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.2%
# Minibatch loss at step 4000: 0.451875
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss at step 4100: 0.350905
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss at step 4200: 0.648884
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 4300: 0.743216
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.0%
# Minibatch loss at step 4400: 1.265506
# Minibatch accuracy: 68.8%
# Validation accuracy: 88.1%
# Minibatch loss at step 4500: 0.642723
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.4%
# Minibatch loss at step 4600: 0.525458
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 4700: 0.383154
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss at step 4800: 0.315338
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 4900: 0.110182
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 5000: 1.058559
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.0%
# Test accuracy: 94.5%
